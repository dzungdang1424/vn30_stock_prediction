# %% [markdown]
# # VN30 Stock Prediction — AI Agent on Colab (GPU)
#
# Sử dụng GPU T4 miễn phí của Google Colab để chạy mô hình ngôn ngữ lớn (Qwen) qua Ollama. Khắc phục lỗi thiếu RAM/VRAM trên máy cá nhân.

# %%
from google.colab import drive
import os
import sys

# 1. Mount Google Drive
drive.mount('/content/drive')

# 2. Chuyển thư mục làm việc (Sửa lại path nếu cần)
PROJECT_PATH = '/content/drive/MyDrive/vn30_stock_prediction'
if os.path.exists(PROJECT_PATH):
    os.chdir(PROJECT_PATH)
    sys.path.append(PROJECT_PATH)
    print(f"✅ Đã chuyển thư mục: {os.getcwd()}")
else:
    print(f"❌ Không tìm thấy {PROJECT_PATH}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ✅ Đã chuyển thư mục: /content/drive/MyDrive/vn30_stock_prediction

# %%
# 3. Cài đặt phần mềm Ollama cho Linux (Colab)
# !curl -fsSL https://ollama.com/install.sh | sh
# Out:
# >>> Installing ollama to /usr/local
# ERROR: This version requires zstd for extraction. Please install zstd and try again:
#   - Debian/Ubuntu: sudo apt-get install zstd
#   - RHEL/CentOS/Fedora: sudo dnf install zstd
#   - Arch: sudo pacman -S zstd

# %%
import subprocess
import time

# 4. Khởi động Ollama Server chạy ngầm (Background)
print("Đang khởi động Ollama server...")
process = subprocess.Popen(['ollama', 'serve'], stdout=subprocess.PIPE, stderr=subprocess.PIPE)
time.sleep(3)  # Đợi vài giây cho server lên
print("✅ Ollama server đã chạy ngầm thành công!")

# %%
# 5. Tải Model ngôn ngữ lớn (Tận dụng GPU T4 16GB)
# Bạn có thể thay đổi tên model ở đây (VD: qwen3.6 hoặc qwen:7b)
# !ollama pull qwen3.6

# %%
# 6. Cài đặt thư viện của dự án
# !pip install -r requirements.txt

# %%
# 7. KÍCH HOẠT TRỢ LÝ AI (Giao diện Chat)
# Ô nhập liệu (Input) sẽ xuất hiện ngay bên dưới ô code này.
# !python main.py --mode chat
